# %% [markdown]
# # 🎬 Cryptoriez Shorts Helper - Example UsageDit notebook toont hoe je de app kunt gebruiken en testen.

# %%
# Test importsimport syssys.path.append("..")from app import GenerationRequest, build_user_prompt, SYSTEM_PROMPTprint("✅ Imports succesvol!")
